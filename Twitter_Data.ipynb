# %%
import pandas as pd
import numpy as np
import datetime as dt
import os

# %%
#path= os.path.join("Resources","algo_returns.csv")
#algo= pd.read_csv(path)
df = pd.read_csv('tweets_sentiment.csv', index_col="created_at", infer_datetime_format=True, parse_dates=True)
# Out:
# /Users/amiraali/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#                                                     Unnamed: 0  \
# created_at
# 2013-01-04 11:48:17 Hora PadrÃ£o do PacÃ­fico (...      378234
# 2013-01-07 18:17:32 Hora PadrÃ£o do PacÃ­fico (...      378235
# 2013-01-30 17:07:29 Hora Padrão do Pacífico (EUA)       697268
# 2013-02-17 12:12:02 Hora PadrÃ£o do PacÃ­fico (...      378236
# 2013-02-26 15:44:15 Hora PadrÃ£o do PacÃ­fico (...      378237
#
#                                                                     id  \
# created_at
# 2013-01-04 11:48:17 Hora PadrÃ£o do PacÃ­fico (...  287000000000000000
# 2013-01-07 18:17:32 Hora PadrÃ£o do PacÃ­fico (...  288000000000000000
# 2013-01-30 17:07:29 Hora Padrão do Pacífico (EUA)   296787000000000000
# 2013-02-17 12:12:02 Hora PadrÃ£o do PacÃ­fico (...  303000000000000000
# 2013-02-26 15:44:15 Hora PadrÃ£o do PacÃ­fico (...  307000000000000000
#
#                                                        conversation_id   date  \
# created_at
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'conversation_id', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest', 'search', 'decoded_tweet', 'neg', 'neu', 'pos',
#        'compound'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0', 'id','quote_url', 'video',
       'thumbnail', 'near', 'user_rt_id', 'user_rt',
       'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
       'trans_dest', 'decoded_tweet', 'neg', 'neu', 'pos',
       'compound','photos','conversation_id'], inplace = True)

# %%
ethdf=df[df['search'].str.contains("ethereum")]
ethdf
# Out:
#                                                      date      time  timezone  \
# created_at
# 2013-01-30 17:07:29 Hora Padrão do Pacífico (EUA)   41304  0.713530      -800
# 2013-09-05 19:35:25 Hor. de Verão do Pacífico (...  41522  0.816262      -800
# 2013-10-02 23:17:18 Hor. de Verão do Pacífico (...  41549  0.970347      -800
# 2013-10-13 16:37:17 Hor. de Verão do Pacífico (...  41560  0.692558      -800
# 2013-10-23 20:24:45 Hor. de Verão do Pacífico (...  41570  0.850521      -800
# ...                                                   ...       ...       ...
# 2021-02-10 15:35:45 Hora Padrão do Pacífico (EUA)   44237  0.649826      -800
# 2021-02-10 15:44:25 Hora Padrão do Pacífico (EUA)   44237  0.655845      -800
# 2021-02-10 15:44:25 Hora Padrão do Pacífico (EUA)   44237  0.655845      -800
# 2021-02-10 15:46:05 Hora Padrão do Pacífico (EUA)   44237  0.657002      -800
# 2021-02-10 15:48:27 Hora Padrão do Pacífico (EUA)   44237  0.658646      -800
#
# ...

# %%
ethdf.to_csv("Eth_Twitter_Data.csv")
