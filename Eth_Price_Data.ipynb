# %%
 # Import libraries and dependencies
import os
import pandas as pd
import alpaca_trade_api as tradeapi

# Load .env environment variables
from dotenv import load_dotenv
load_dotenv()

# %matplotlib inline

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2016-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2016-12-31", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker = alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
).df

# Display sample data
df_ticker.head(10)
# Out:
#                           exchange   open   high    low  close     volume  \
# timestamp
# 2016-05-18 00:14:00+00:00     CBSE  12.50  12.50  12.50  12.50   0.399002
# 2016-05-18 00:25:00+00:00     CBSE  12.50  13.00  12.50  13.00   0.790428
# 2016-05-18 00:36:00+00:00     CBSE  12.75  12.75  12.75  12.75   0.589115
# 2016-05-18 00:38:00+00:00     CBSE  12.75  13.00  12.75  13.00   5.083098
# 2016-05-18 00:39:00+00:00     CBSE  13.00  13.00  13.00  13.00   0.638356
# 2016-05-18 00:47:00+00:00     CBSE  14.93  14.93  14.93  14.93   0.002848
# 2016-05-18 00:59:00+00:00     CBSE  13.00  13.00  13.00  13.00   0.500000
# 2016-05-18 01:05:00+00:00     CBSE  14.00  14.00  14.00  14.00   0.462483
# 2016-05-18 01:28:00+00:00     CBSE  14.00  14.10  14.00  14.10  15.000000
# 2016-05-18 02:03:00+00:00     CBSE  14.00  14.00  14.00  14.00   0.052000
#
#                            trade_count       vwap  symbol
# timestamp
# 2016-05-18 00:14:00+00:00            1  12.500000  ETHUSD
# ...

# %%
df_ticker.to_csv("Eth_Price_2016.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2017-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2017-06-30", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20171 = alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
).df

# Display sample data
df_ticker_20171.head(10)
# Out:
#                           exchange  open  high   low  close    volume  \
# timestamp
# 2017-01-01 05:00:00+00:00     CBSE  8.53  8.53  8.53   8.53  10.41063
# 2017-01-01 05:02:00+00:00     CBSE  8.54  8.54  8.54   8.54   0.12793
# 2017-01-01 05:03:00+00:00     CBSE  8.53  8.53  8.53   8.53  10.00000
# 2017-01-01 05:08:00+00:00     CBSE  8.51  8.51  8.51   8.51   1.12120
# 2017-01-01 05:09:00+00:00     CBSE  8.53  8.53  8.53   8.53   7.94154
# 2017-01-01 05:10:00+00:00     CBSE  8.52  8.53  8.52   8.53  73.00000
# 2017-01-01 05:11:00+00:00     CBSE  8.51  8.51  8.50   8.50  26.11781
# 2017-01-01 05:12:00+00:00     CBSE  8.50  8.50  8.50   8.50  68.00000
# 2017-01-01 05:15:00+00:00     CBSE  8.52  8.52  8.52   8.52  31.65168
# 2017-01-01 05:16:00+00:00     CBSE  8.50  8.50  8.50   8.50  31.65000
#
#                            trade_count      vwap  symbol
# timestamp
# 2017-01-01 05:00:00+00:00            1  8.530000  ETHUSD
# 2017-01-01 05:02:00+00:00            1  8.540000  ETHUSD
# ...

# %%
df_ticker_20171.to_csv("Eth_Price_20171.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2017-07-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2017-12-31", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20172 = alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
).df

# Display sample data
df_ticker_20172.head(10)
# Out:
#                           exchange    open    high     low   close     volume  \
# timestamp
# 2017-07-01 04:00:00+00:00     CBSE  272.09  272.10  272.09  272.10  38.679700
# 2017-07-01 04:01:00+00:00     CBSE  272.09  272.10  272.09  272.10  31.481503
# 2017-07-01 04:02:00+00:00     CBSE  272.10  272.10  272.09  272.10  29.914518
# 2017-07-01 04:03:00+00:00     CBSE  272.09  272.09  272.09  272.09   0.050000
# 2017-07-01 04:04:00+00:00     CBSE  272.10  272.10  272.09  272.10  24.807422
# 2017-07-01 04:05:00+00:00     CBSE  272.10  272.10  272.09  272.09  39.316821
# 2017-07-01 04:06:00+00:00     CBSE  272.10  272.10  272.10  272.10   3.814432
# 2017-07-01 04:07:00+00:00     CBSE  272.10  272.10  272.10  272.10   6.249833
# 2017-07-01 04:08:00+00:00     CBSE  272.10  272.10  272.09  272.09  13.139500
# 2017-07-01 04:09:00+00:00     CBSE  272.10  272.10  272.09  272.09  18.898095
#
#                            trade_count        vwap  symbol
# timestamp
# ...

# %%
df_ticker_20172.to_csv("Eth_Price_20172.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2018-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2018-06-30", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20181= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date
).df

# Display sample data
df_ticker_20181.head(10)
# Out:
#                           exchange    open    high     low   close  \
# timestamp
# 2018-01-01 05:00:00+00:00     CBSE  747.90  747.91  747.90  747.91
# 2018-01-01 05:01:00+00:00     CBSE  747.91  747.91  747.90  747.90
# 2018-01-01 05:02:00+00:00     CBSE  747.91  747.91  745.50  745.50
# 2018-01-01 05:03:00+00:00     CBSE  746.82  746.82  745.72  745.96
# 2018-01-01 05:04:00+00:00     CBSE  745.99  746.50  745.99  746.50
# 2018-01-01 05:05:00+00:00     CBSE  746.31  746.90  746.00  746.23
# 2018-01-01 05:06:00+00:00     CBSE  746.25  746.25  745.72  745.72
# 2018-01-01 05:07:00+00:00     CBSE  745.73  745.73  743.34  743.37
# 2018-01-01 05:08:00+00:00     CBSE  743.36  743.37  742.35  742.36
# 2018-01-01 05:09:00+00:00     CBSE  742.35  742.35  742.01  742.01
#
#                                volume  trade_count        vwap  symbol
# timestamp
# 2018-01-01 05:00:00+00:00    6.601531           41  747.904125  ETHUSD
# ...

# %%
df_ticker_20181.to_csv("Eth_Price_20181.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2018-07-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2018-12-31", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20182= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date
).df

# Display sample data
df_ticker_20182.head(10)
# Out:
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
#                           exchange    open    high     low   close     volume  \
# timestamp
# 2018-07-01 04:00:00+00:00     CBSE  450.01  450.01  450.00  450.01  11.040296
# 2018-07-01 04:01:00+00:00     CBSE  450.01  450.01  450.00  450.01   1.238040
# 2018-07-01 04:02:00+00:00     CBSE  450.01  450.01  450.00  450.01   4.385479
# 2018-07-01 04:03:00+00:00     CBSE  450.01  450.01  450.00  450.01  10.566873
# 2018-07-01 04:04:00+00:00     CBSE  450.00  450.00  449.89  449.90  11.538942
# 2018-07-01 04:05:00+00:00     CBSE  449.89  449.89  449.64  449.64   5.779878
# 2018-07-01 04:06:00+00:00     CBSE  449.65  449.65  449.63  449.63   1.237100
# 2018-07-01 04:07:00+00:00     CBSE  449.64  449.65  449.63  449.65  32.221100
# ...

# %%
df_ticker_20182.to_csv("Eth_Price_20182.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2019-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2019-06-30", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20191= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
).df

# Display sample data
df_ticker_20191.head(10)
# Out:
#                           exchange    open    high     low   close  \
# timestamp
# 2019-01-01 05:00:00+00:00     CBSE  132.12  132.26  132.07  132.25
# 2019-01-01 05:01:00+00:00     CBSE  132.23  132.58  132.23  132.33
# 2019-01-01 05:02:00+00:00     CBSE  132.34  132.34  132.33  132.33
# 2019-01-01 05:03:00+00:00     CBSE  132.33  132.34  132.20  132.20
# 2019-01-01 05:04:00+00:00     CBSE  132.30  132.32  132.28  132.32
# 2019-01-01 05:05:00+00:00     CBSE  132.31  132.32  132.24  132.24
# 2019-01-01 05:06:00+00:00     CBSE  132.23  132.30  132.18  132.23
# 2019-01-01 05:07:00+00:00     CBSE  132.20  132.20  132.12  132.12
# 2019-01-01 05:08:00+00:00     CBSE  132.16  132.17  132.05  132.05
# 2019-01-01 05:09:00+00:00     CBSE  132.12  132.12  132.10  132.10
#
#                                volume  trade_count        vwap  symbol
# timestamp
# 2019-01-01 05:00:00+00:00   53.433061           16  132.181948  ETHUSD
# ...

# %%
df_ticker_20191.to_csv("Eth_Price_20191.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2019-07-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2019-12-31", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20192= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
).df

# Display sample data
df_ticker_20192.head(10)
# Out:
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
#                           exchange    open    high     low   close     volume  \
# timestamp
# 2019-07-01 04:00:00+00:00     CBSE  298.11  298.57  298.01  298.57  10.156186
# 2019-07-01 04:01:00+00:00     CBSE  298.45  298.66  298.43  298.50  12.673028
# ...

# %%
df_ticker_20192.to_csv("Eth_Price_20192.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2020-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-06-30", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20201= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
).df

# Display sample data
df_ticker_20201.head(10)
# Out:
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
#                           exchange    open    high     low   close  \
# timestamp
# 2020-01-01 05:00:00+00:00     CBSE  129.55  129.57  129.54  129.57
# 2020-01-01 05:01:00+00:00     CBSE  129.56  129.64  129.56  129.64
# ...

# %%
df_ticker_20201.to_csv("Eth_Price_20201.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2020-07-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-12-31", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20202= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date
    ).df

# Display sample data
df_ticker_20202.head(10)
# Out:
#                           exchange    open    high     low   close  \
# timestamp
# 2020-07-01 04:00:00+00:00     CBSE  225.40  225.67  225.40  225.67
# 2020-07-01 04:01:00+00:00     CBSE  225.66  225.75  225.60  225.64
# 2020-07-01 04:02:00+00:00     CBSE  225.64  225.78  225.64  225.76
# 2020-07-01 04:03:00+00:00     CBSE  225.76  225.76  225.66  225.75
# 2020-07-01 04:04:00+00:00     CBSE  225.72  225.76  225.72  225.74
# 2020-07-01 04:05:00+00:00     CBSE  225.73  225.74  225.52  225.52
# 2020-07-01 04:06:00+00:00     CBSE  225.51  225.62  225.51  225.58
# 2020-07-01 04:07:00+00:00     CBSE  225.56  225.61  225.56  225.56
# 2020-07-01 04:08:00+00:00     CBSE  225.56  225.61  225.55  225.56
# 2020-07-01 04:09:00+00:00     CBSE  225.56  225.69  225.56  225.69
#
#                                volume  trade_count        vwap  symbol
# timestamp
# 2020-07-01 04:00:00+00:00    9.990407           13  225.457064  ETHUSD
# ...

# %%
df_ticker_20202.to_csv("Eth_Price_20202.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2021-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2021-06-30", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20211= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date
    ).df

# Display sample data
df_ticker_20211.head(10)
# Out:
#                           exchange    open    high     low   close  \
# timestamp
# 2021-01-01 05:00:00+00:00     CBSE  743.58  744.24  743.40  744.18
# 2021-01-01 05:01:00+00:00     CBSE  744.17  744.51  743.80  743.80
# 2021-01-01 05:02:00+00:00     CBSE  743.81  743.82  743.01  743.02
# 2021-01-01 05:03:00+00:00     CBSE  743.01  743.01  741.50  741.50
# 2021-01-01 05:03:00+00:00     FTXU  742.78  742.78  742.78  742.78
# 2021-01-01 05:04:00+00:00     CBSE  741.63  743.02  741.62  742.69
# 2021-01-01 05:05:00+00:00     CBSE  742.20  743.10  741.90  742.62
# 2021-01-01 05:06:00+00:00     CBSE  742.54  742.88  742.50  742.83
# 2021-01-01 05:07:00+00:00     CBSE  742.81  742.81  741.96  742.61
# 2021-01-01 05:08:00+00:00     CBSE  742.60  742.60  741.57  742.15
#
#                                volume  trade_count        vwap  symbol
# timestamp
# 2021-01-01 05:00:00+00:00  133.964910           69  743.938503  ETHUSD
# ...

# %%
df_ticker_20211.to_csv("Eth_Price_20211.csv")

# %%
# Set tickers
ticker = ["ETHUSD"]

# Set timeframe to '1Minute'
timeframe = "1Min"

# Set start and end datetimes.
start_date = pd.Timestamp("2021-07-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2021-12-31", tz="America/New_York").isoformat()

# Get 1 year's 
df_ticker_20212= alpaca.get_crypto_bars(
    ticker,
    timeframe,
    start=start_date,
    end=end_date
    ).df

# Display sample data
df_ticker_20212.head(10)
# Out:
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
# sleep 3 seconds and retrying https://data.alpaca.markets/v1beta1/crypto/bars 3 more time(s)...
#                           exchange     open     high      low    close  \
# timestamp
# 2021-07-01 04:00:00+00:00     CBSE  2185.09  2189.02  2185.00  2185.01
# 2021-07-01 04:01:00+00:00     CBSE  2185.00  2191.33  2184.27  2190.51
# 2021-07-01 04:01:00+00:00     FTXU  2189.20  2190.20  2189.20  2190.20
# 2021-07-01 04:02:00+00:00     CBSE  2190.76  2191.18  2189.92  2190.38
# 2021-07-01 04:03:00+00:00     CBSE  2190.39  2191.43  2187.43  2188.86
# 2021-07-01 04:03:00+00:00     FTXU  2190.00  2190.00  2190.00  2190.00
# 2021-07-01 04:04:00+00:00     CBSE  2188.89  2189.10  2182.20  2182.20
# ...

# %%
df_ticker_20212.to_csv("Eth_Price_20212.csv")

# %%
df16 = pd.read_csv('Eth_Price_2016.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df171=pd.read_csv('Eth_Price_20171.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df172=pd.read_csv('Eth_Price_20172.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df181=pd.read_csv('Eth_Price_20181.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df182=pd.read_csv('Eth_Price_20182.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df191=pd.read_csv('Eth_Price_20191.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df192=pd.read_csv('Eth_Price_20192.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df201=pd.read_csv('Eth_Price_20201.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df202=pd.read_csv('Eth_Price_20202.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df211=pd.read_csv('Eth_Price_20211.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)
df212=pd.read_csv('Eth_Price_20212.csv', index_col="timestamp", infer_datetime_format=True, parse_dates=True)

# %%
dfs = [df16, df171, df172, df181, df182, df191, df192, df201, df202, df211, df212]

# %%
import pandas
total_eth_df=pandas.concat([df16, df171, df172, df181, df182, df191, df192, df201, df202, df211, df212], axis=0, join='outer')
total_eth_df
# Out:
#                           exchange     open     high      low    close  \
# timestamp
# 2016-05-18 00:14:00+00:00     CBSE    12.50    12.50    12.50    12.50
# 2016-05-18 00:25:00+00:00     CBSE    12.50    13.00    12.50    13.00
# 2016-05-18 00:36:00+00:00     CBSE    12.75    12.75    12.75    12.75
# 2016-05-18 00:38:00+00:00     CBSE    12.75    13.00    12.75    13.00
# 2016-05-18 00:39:00+00:00     CBSE    13.00    13.00    13.00    13.00
# ...                            ...      ...      ...      ...      ...
# 2021-12-31 04:57:00+00:00     CBSE  3750.96  3752.09  3749.04  3749.07
# 2021-12-31 04:58:00+00:00     CBSE  3749.54  3750.93  3747.67  3749.00
# 2021-12-31 04:59:00+00:00     CBSE  3749.02  3749.95  3741.10  3746.82
# 2021-12-31 05:00:00+00:00     CBSE  3746.82  3753.49  3746.53  3750.39
# 2021-12-31 05:00:00+00:00     FTXU  3749.40  3751.60  3749.40  3751.60
#
#                                volume  trade_count         vwap  symbol
# timestamp
# ...

# %%
total_eth_df.to_csv("Total_Eth_Prices.csv")
