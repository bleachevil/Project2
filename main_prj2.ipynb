# %%
# utilities
import pandas as pd
import numpy as np
import re
import string
string.punctuation
# nltk
# import nltk
# from nltk.corpus import stopwords
# nltk.download('stopwords')
# from nltk.stem import PorterStemmer

from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

# %%
# Read and Load the dataset

tweets_df = pd.read_csv('Eth_Twitter_Data.csv',
                 index_col='created_at',
                 infer_datetime_format=True,
                 parse_dates=True
)

# %%
tweets_df.head(10)
# Out:
#                                                                  tweet
# created_at
# 2013-01-30 17:07:29  Attention ye who have not children: Chooseth w...
# 2013-09-05 19:35:25  Unite knows something we dont... something bet...
# 2013-10-02 23:17:18  ok i have to ask... why do people favorite twe...
# 2013-10-13 16:37:17                             M(eth)iley C(rack)yrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48           . if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away. Shoul...
# 2014-01-23 12:05:09  we're about to get roasted and people might no...
# 2014-01-26 22:32:51                              tK would be needing 1

# %%
tweets_df.shape
# Out:
# (86336, 1)

# %%
tweets_df.dtypes
# Out:
# tweet    object
# dtype: object

# %%
tweets_df.isnull().sum()
# Out:
# tweet    0
# dtype: int64

# %%
tweets_df.dropna(inplace=True)

# %%
tweets_df.shape
# Out:
# (86336, 1)

# %%
tweets_df.drop_duplicates(inplace=True)
tweets_df.shape[0]
# Out:
# 78533

# %%
# function to clean the tweets
def cleanTwt(twt):
    twt = re.sub('@[A-Za-z0-9]+', ' ', twt)
    twt = re.sub('[^A-Za-z0-9]+', ' ', twt) # Add a new regex
    twt = re.sub('\\n', '', twt)
    twt = re.sub('\\t', '', twt)
    twt = re.sub('(www.[^s]+)|(https?:\/\/\S+)', ' ', twt)
    twt = twt.lower()
    return twt

# %%
#defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree = "".join([i for i in text if i not in string.punctuation])
    return punctuationfree

# %%
#storing the puntuation free text
tweets_df['cleaned_tweets'] = tweets_df['tweet'].apply(remove_punctuation)

# %%
tweets_df.head(10)
# Out:
#                                                                  tweet  \
# created_at
# 2013-01-30 17:07:29  Attention ye who have not children: Chooseth w...
# 2013-09-05 19:35:25  Unite knows something we dont... something bet...
# 2013-10-02 23:17:18  ok i have to ask... why do people favorite twe...
# 2013-10-13 16:37:17                             M(eth)iley C(rack)yrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48           . if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away. Shoul...
# 2014-01-23 12:05:09  we're about to get roasted and people might no...
# 2014-01-26 22:32:51                              tK would be needing 1
#
#                                                         cleaned_tweets
# created_at
# 2013-01-30 17:07:29  Attention ye who have not children Chooseth wi...
# 2013-09-05 19:35:25  Unite knows something we dont something better...
# 2013-10-02 23:17:18  ok i have to ask why do people favorite tweets...
# 2013-10-13 16:37:17                                 Methiley Crackyrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48             if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away Should...
# 2014-01-23 12:05:09  were about to get roasted and people might not...
# 2014-01-26 22:32:51                              tK would be needing 1

# %%
# Clean the tweets
tweets_df['cleaned_tweets'] = tweets_df['cleaned_tweets'].apply(cleanTwt)

# %%
tweets_df.head(10)
# Out:
#                                                                  tweet  \
# created_at
# 2013-01-30 17:07:29  Attention ye who have not children: Chooseth w...
# 2013-09-05 19:35:25  Unite knows something we dont... something bet...
# 2013-10-02 23:17:18  ok i have to ask... why do people favorite twe...
# 2013-10-13 16:37:17                             M(eth)iley C(rack)yrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48           . if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away. Shoul...
# 2014-01-23 12:05:09  we're about to get roasted and people might no...
# 2014-01-26 22:32:51                              tK would be needing 1
#
#                                                         cleaned_tweets
# created_at
# 2013-01-30 17:07:29  attention ye who have not children chooseth wi...
# 2013-09-05 19:35:25  unite knows something we dont something better...
# 2013-10-02 23:17:18  ok i have to ask why do people favorite tweets...
# 2013-10-13 16:37:17                                 methiley crackyrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48             if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away should...
# 2014-01-23 12:05:09  were about to get roasted and people might not...
# 2014-01-26 22:32:51                              tk would be needing 1

# %%
# Create a function to get the sentiment text
def getSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
# Create a function to get the subjectivity
def getSubjectivity(twt):
    return TextBlob(twt).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(twt):
    return TextBlob(twt).sentiment.polarity

# %%
# Create two new columns called 'Subjectivity' and 'Polarity'
tweets_df['subjectivity'] = tweets_df['cleaned_tweets'].apply(getSubjectivity)
tweets_df['polarity'] = tweets_df['cleaned_tweets'].apply(getPolarity)

# %%
tweets_df.head(10)
# Out:
#                                                                  tweet  \
# created_at
# 2013-01-30 17:07:29  Attention ye who have not children: Chooseth w...
# 2013-09-05 19:35:25  Unite knows something we dont... something bet...
# 2013-10-02 23:17:18  ok i have to ask... why do people favorite twe...
# 2013-10-13 16:37:17                             M(eth)iley C(rack)yrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48           . if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away. Shoul...
# 2014-01-23 12:05:09  we're about to get roasted and people might no...
# 2014-01-26 22:32:51                              tK would be needing 1
#
#                                                         cleaned_tweets  \
# created_at
# 2013-01-30 17:07:29  attention ye who have not children chooseth wi...
# 2013-09-05 19:35:25  unite knows something we dont something better...
# 2013-10-02 23:17:18  ok i have to ask why do people favorite tweets...
# 2013-10-13 16:37:17                                 methiley crackyrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48             if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away should...
# 2014-01-23 12:05:09  were about to get roasted and people might not...
# 2014-01-26 22:32:51                              tk would be needing 1
#
#                      subjectivity  polarity
# created_at
# 2013-01-30 17:07:29      0.900000    0.7000
# 2013-09-05 19:35:25      0.416667    0.3750
# 2013-10-02 23:17:18      0.750000    0.1875
# 2013-10-13 16:37:17      0.000000    0.0000
# 2013-10-23 20:24:45      0.000000    0.0000
# 2013-10-23 20:26:11      0.600000   -0.1000
# 2013-12-08 17:41:48      1.000000   -0.5000
# 2014-01-12 23:53:00      0.000000    0.0000
# 2014-01-23 12:05:09      0.000000    0.0000
# 2014-01-26 22:32:51      0.000000    0.0000

# %%
# Create a column to store the text sentiment
tweets_df['sentiment'] = tweets_df['polarity'].apply(getSentiment)

# %%
tweets_df.head(10)
# Out:
#                                                                  tweet  \
# created_at
# 2013-01-30 17:07:29  Attention ye who have not children: Chooseth w...
# 2013-09-05 19:35:25  Unite knows something we dont... something bet...
# 2013-10-02 23:17:18  ok i have to ask... why do people favorite twe...
# 2013-10-13 16:37:17                             M(eth)iley C(rack)yrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48           . if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away. Shoul...
# 2014-01-23 12:05:09  we're about to get roasted and people might no...
# 2014-01-26 22:32:51                              tK would be needing 1
#
#                                                         cleaned_tweets  \
# created_at
# 2013-01-30 17:07:29  attention ye who have not children chooseth wi...
# 2013-09-05 19:35:25  unite knows something we dont something better...
# 2013-10-02 23:17:18  ok i have to ask why do people favorite tweets...
# 2013-10-13 16:37:17                                 methiley crackyrus
# 2013-10-23 20:24:45                   get a sled and ride it out homie
# 2013-10-23 20:26:11  tell me i didnt just hit methodz with some dee...
# 2013-12-08 17:41:48             if you get a million ill start smoking
# 2014-01-12 23:53:00  give it a month and it will all go away should...
# 2014-01-23 12:05:09  were about to get roasted and people might not...
# 2014-01-26 22:32:51                              tk would be needing 1
#
#                      subjectivity  polarity sentiment
# created_at
# 2013-01-30 17:07:29      0.900000    0.7000  Positive
# 2013-09-05 19:35:25      0.416667    0.3750  Positive
# 2013-10-02 23:17:18      0.750000    0.1875  Positive
# 2013-10-13 16:37:17      0.000000    0.0000   Neutral
# 2013-10-23 20:24:45      0.000000    0.0000   Neutral
# 2013-10-23 20:26:11      0.600000   -0.1000  Negative
# 2013-12-08 17:41:48      1.000000   -0.5000  Negative
# 2014-01-12 23:53:00      0.000000    0.0000   Neutral
# 2014-01-23 12:05:09      0.000000    0.0000   Neutral
# 2014-01-26 22:32:51      0.000000    0.0000   Neutral

# %%
# sentiment confidence?
# bag of words?
# stemming/lemmatization on tweets?
# get dummies for 

# Easy classifier
# Random forest
# Multinomial NB (Naive Bayes) --> supervised learning that works well with text based data

# final -- create a bot for the buy/sell signal

# %%
# Convert the sentiments into numbers for representation
# negative = 0, neutral = 1, positive = 2

sentiment_ordering = ['Negative', 'Neutral', 'Positive']
tweets_df['sentiment_score'] = tweets_df['sentiment'].apply(lambda x: sentiment_ordering.index(x))

# tweets_df.head(10)
tweets_df.tail(10)
# Out:
#                                                                  tweet  \
# created_at
# 2021-02-10 15:28:47  End/ But, to me, $ETH is simply a pipeline and...
# 2021-02-10 15:30:00  applications incubator has completed the trans...
# 2021-02-10 15:30:52  Someone just lost $69,261 (~39.48 ETH)! 69,260...
# 2021-02-10 15:35:14                                     eth is so done
# 2021-02-10 15:35:34  Another piece of a piece I’ve been waiting to ...
# 2021-02-10 15:35:45  Someone has a buy order right now for 800K+ $D...
# 2021-02-10 15:44:25  LAST public service announcement I'll make bef...
# 2021-02-10 15:44:25  It is ~1/100th the value of $eth. I won't ment...
# 2021-02-10 15:46:05  Complaints about $AVAX, a 6 month(!!) old proj...
# 2021-02-10 15:48:27  One of the reasons that $ORN is a magnificent ...
#
#                                                         cleaned_tweets  \
# created_at
# 2021-02-10 15:28:47  end but to me eth is simply a pipeline and lin...
# 2021-02-10 15:30:00  applications incubator has completed the trans...
# 2021-02-10 15:30:52  someone just lost 69261 3948 eth 69260502 usdt...
# 2021-02-10 15:35:14                                     eth is so done
# 2021-02-10 15:35:34  another piece of a piece i ve been waiting to ...
# 2021-02-10 15:35:45  someone has a buy order right now for 800k drg...
# 2021-02-10 15:44:25  last public service announcement ill make befo...
# 2021-02-10 15:44:25  it is 1100th the value of eth i wont mention i...
# 2021-02-10 15:46:05  complaints about avax a 6 month old project ha...
# 2021-02-10 15:48:27  one of the reasons that orn is a magnificent p...
#
#                      subjectivity  polarity sentiment  sentiment_score
# created_at
# 2021-02-10 15:28:47      0.714286  0.125000  Positive                2
# 2021-02-10 15:30:00      0.000000  0.000000   Neutral                1
# 2021-02-10 15:30:52      0.500000  0.000000   Neutral                1
# 2021-02-10 15:35:14      0.000000  0.000000   Neutral                1
# 2021-02-10 15:35:34      0.550000  0.500000  Positive                2
# 2021-02-10 15:35:45      0.535714  0.285714  Positive                2
# 2021-02-10 15:44:25      0.505556 -0.187500  Negative                0
# 2021-02-10 15:44:25      0.533333  0.000000   Neutral                1
# 2021-02-10 15:46:05      0.531250  0.062500  Positive                2
# 2021-02-10 15:48:27      0.758333  0.616667  Positive                2

# %%
# cv = CountVectorizer(max_features=3000)
# X = cv.fit_transform(tweets_df['cleaned_tweets']).toarray()
# y = tweets_df[['sentiment_score']]

# %%
# model = MultinomialNB()

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# model.fit(X_train, y_train)

# %%
# y_pred = model.predict(X_test)

# %%
# cf = classification_report(y_test, y_pred)
# print(cf)

# %%
# cf_acc = accuracy_score(y_pred, y_test)
# print("Test Accuracy: {:.2f}%".format(cf_acc*100))
